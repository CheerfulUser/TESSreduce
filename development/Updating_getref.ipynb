# %%
from tessreduce import *
# %matplotlib notebook

# %%
tess = tessreduce(tpf='../../../../data/tess/2020fqv.fits',reduce=True)
# Out:
# made reference
# made source mask
# calculating background
# background subtracted
# calculating centroids
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# Field calibration
# <img src="data:image/png;base64,..." width="996">

# %%
tess.ref_ind
# Out:
# 968

# %%
plt.figure()
plt.imshow(tess.flux[tess.ref_ind] - tess.flux[tess.ref_ind-10],vmax=10,vmin=-10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.imshow(tess.mask)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.imshow(tess.tpf.flux[100].value-(tess.ref))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tess.flux -= tess.flux[100]

# %%
tess.diff_lc(plot=True)
# Out:
# <img src="data:image/png;base64,..." width="996">
# (array([[ 5.89276205e+04,  5.89276414e+04,  5.89276622e+04, ...,
#           5.89543286e+04,  5.89543494e+04,  5.89543703e+04],
#         [            nan,             nan,             nan, ...,
#          -2.64645721e+02, -2.61346527e+02, -2.57721436e+02],
#         [            nan,             nan,             nan, ...,
#           3.48773575e+00,  3.49024868e+00,  3.46138597e+00]]),
#  array([[5.89276205e+04, 5.89276414e+04, 5.89276622e+04, ...,
#          5.89543286e+04, 5.89543494e+04, 5.89543703e+04],
#         [           nan,            nan,            nan, ...,
#          1.19110596e+00, 1.34032357e+00, 1.11009419e+00],
#         [           nan,            nan,            nan, ...,
#          3.48773575e+00, 3.49024868e+00, 3.46138597e+00]]))

# %%
plt.figure()
plt.imshow(tess.flux[1000]-tess.flux[100],vmin=-10,vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.imshow(tess.flux[1000],vmin=-10,vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = tess.tpf.flux.value
ind = tess.tpf.quality==0
d = deepcopy(data)[ind]
summed = np.nansum(d,axis=(1,2))
lim = np.percentile(summed[np.isfinite(summed)],5)
summed[summed>lim] = 0
inds = np.where(ind)[0]
ref_ind = inds[np.argmax(s)]
reference = data[ref_ind]

# %%
plt.figure()
plt.plot(summed)
plt.axhline(lim)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ref_ind
# Out:
# 1188

# %%
plt.figure()
plt.imshow(d[898]-reference)
# Out:
# <img src="data:image/png;base64,..." width="640">
